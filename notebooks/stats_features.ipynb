# %%
import pandas as pd

# %%
df = pd.DataFrame()
for i in range(1,19):
    df = pd.concat([df, pd.read_csv(f"raw_data/data_final_project/E0 ({i}).csv")])
    
df
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E0  05/08/2022  20:00  Crystal Palace        Arsenal   0.0   2.0   A
# 1    E0  06/08/2022  12:30          Fulham      Liverpool   2.0   2.0   D
# 2    E0  06/08/2022  15:00     Bournemouth    Aston Villa   2.0   0.0   H
# 3    E0  06/08/2022  15:00           Leeds         Wolves   2.0   1.0   H
# 4    E0  06/08/2022  15:00       Newcastle  Nott'm Forest   2.0   0.0   H
# ..   ..         ...    ...             ...            ...   ...   ...  ..
# 375  E0    07/05/06    NaN          Fulham  Middlesbrough   1.0   0.0   H
# 376  E0    07/05/06    NaN      Man United       Charlton   4.0   0.0   H
# 377  E0    07/05/06    NaN       Newcastle        Chelsea   1.0   0.0   H
# 378  E0    07/05/06    NaN      Portsmouth      Liverpool   1.0   3.0   A
# 379  E0    07/05/06    NaN        West Ham      Tottenham   2.0   1.0   H
#
#      HTHG  HTAG  ...    SJA  GBH  GBD    GBA  BSH  BSD  BSA  SBH   SBD    SBA
# ...

# %%
stat_cols = ['AC', 'AF', 'AR', 'AS', 'AST', 'AY', 'HC', 'HF', 'HR', 'HS', 'HST', 'HY', 'margin']
df['margin'] = df['FTHG'] - df['FTAG']

# %%
df
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E0  05/08/2022  20:00  Crystal Palace        Arsenal   0.0   2.0   A
# 1    E0  06/08/2022  12:30          Fulham      Liverpool   2.0   2.0   D
# 2    E0  06/08/2022  15:00     Bournemouth    Aston Villa   2.0   0.0   H
# 3    E0  06/08/2022  15:00           Leeds         Wolves   2.0   1.0   H
# 4    E0  06/08/2022  15:00       Newcastle  Nott'm Forest   2.0   0.0   H
# ..   ..         ...    ...             ...            ...   ...   ...  ..
# 375  E0    07/05/06    NaN          Fulham  Middlesbrough   1.0   0.0   H
# 376  E0    07/05/06    NaN      Man United       Charlton   4.0   0.0   H
# 377  E0    07/05/06    NaN       Newcastle        Chelsea   1.0   0.0   H
# 378  E0    07/05/06    NaN      Portsmouth      Liverpool   1.0   3.0   A
# 379  E0    07/05/06    NaN        West Ham      Tottenham   2.0   1.0   H
#
#      HTHG  HTAG  ...  GBH  GBD    GBA  BSH  BSD  BSA  SBH   SBD    SBA  margin
# ...

# %%
df = df.assign(homeWin=lambda df: df.apply(lambda row: 1 if row.FTHG > row.FTAG else 0, axis='columns'),
              draw=lambda df: df.apply(lambda row: 1 if row.FTHG == row.FTAG else 0, axis='columns'),
              awayWin=lambda df: df.apply(lambda row: 1 if row.FTHG < row.FTAG else 0, axis='columns'))

# %%
df.columns.values
# Out:
# array(['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG',
#        'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST',
#        'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D',
#        'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD',
#        'PSA', 'WHH', 'WHD', 'WHA', 'VCH', 'VCD', 'VCA', 'MaxH', 'MaxD',
#        'MaxA', 'AvgH', 'AvgD', 'AvgA', 'B365>2.5', 'B365<2.5', 'P>2.5',
#        'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'AHh',
#        'B365AHH', 'B365AHA', 'PAHH', 'PAHA', 'MaxAHH', 'MaxAHA', 'AvgAHH',
#        'AvgAHA', 'B365CH', 'B365CD', 'B365CA', 'BWCH', 'BWCD', 'BWCA',
#        'IWCH', 'IWCD', 'IWCA', 'PSCH', 'PSCD', 'PSCA', 'WHCH', 'WHCD',
#        'WHCA', 'VCCH', 'VCCD', 'VCCA', 'MaxCH', 'MaxCD', 'MaxCA', 'AvgCH',
#        'AvgCD', 'AvgCA', 'B365C>2.5', 'B365C<2.5', 'PC>2.5', 'PC<2.5',
#        'MaxC>2.5', 'MaxC<2.5', 'AvgC>2.5', 'AvgC<2.5', 'AHCh', 'B365CAHH',
# ...

# %%
df_home['AR'].mean()
# Out:
# 0.07948074940185823

# %%
df_home['AY'].mean()
# Out:
# 1.7210319556169755

# %%
df_home['HR'].mean()
# Out:
# 0.061367007200299584

# %%
df_home['HY'].mean()
# Out:
# 1.521816107933942

# %%
df_home['AS'].mean()
# Out:
# 11.656925435196094

# %%
df_home['HS'].mean()
# Out:
# 12.869136184029019

# %%
df_home['AST'].mean()
# Out:
# 5.050180175325731

# %%
df_home['HST'].mean()
# Out:
# 5.468692273041323

# %%
df_home['AF'].mean()
# Out:
# 11.275495104198152

# %%
df_home['HF'].mean()
# Out:
# 11.09841958816023

# %%
print(np.array(df_home['AC']))
# Out:
# [4.00299401 5.70503597 5.72368421 5.21052632 6.47368421 5.54135338
#  5.25233645 5.4516129  4.33018868 5.44078947 6.18421053 6.28947368
#  3.92814371 5.07608696 5.15789474 4.91071429 5.47297297 4.07894737
#  5.4        4.58       4.9695122  3.54491018 3.79701493 3.84179104
#  5.03157895 4.81818182 5.52631579 5.5        5.48421053 6.38596491
#  5.21052632 5.38596491 4.80597015 5.39473684 4.94736842 4.5112782
#  4.48511905 4.92481203 4.98564593 5.18987342 4.55263158 4.66206897]

# %%
df_home = df.groupby(df['HomeTeam'])[stat_cols].mean()
df_home
# Out:
#                         AC         AF        AR         AS       AST  \
# HomeTeam
# Arsenal           4.002994  11.949102  0.116766   9.017964  3.790419
# Aston Villa       5.705036  11.812950  0.100719  11.546763  5.359712
# Birmingham        5.723684  12.657895  0.052632  12.131579  5.960526
# Blackburn         5.210526  12.308271  0.112782  10.894737  5.954887
# Blackpool         6.473684  10.631579  0.157895  13.684211  8.000000
# Bolton            5.541353  11.947368  0.022556  11.571429  6.511278
# Bournemouth       5.252336  11.990654  0.093458  13.065421  4.336449
# Brentford         5.451613   9.935484  0.064516  12.612903  4.451613
# Brighton          4.330189   9.169811  0.037736  10.952830  3.849057
# Burnley           5.440789  10.855263  0.065789  13.743421  4.809211
# Cardiff           6.184211  11.342105  0.105263  15.052632  5.500000
# Charlton          6.289474  12.500000  0.052632  12.263158  6.263158
# ...

# %%
df_away = df.groupby(df['AwayTeam'])[stat_cols].mean()
df_away
# Out:
#                         AC         AF        AR         AS       AST  \
# AwayTeam
# Arsenal           5.226190  10.226190  0.113095  12.613095  5.642857
# Aston Villa       4.884892  12.197842  0.061151  10.165468  4.622302
# Birmingham        4.276316  12.276316  0.092105   8.026316  4.460526
# Blackburn         4.827068  12.924812  0.135338   9.338346  5.105263
# Blackpool         4.842105   9.842105  0.105263  10.157895  5.315789
# Bolton            4.804511  13.270677  0.105263   9.609023  4.954887
# Bournemouth       4.803738   9.467290  0.037383  10.383178  3.588785
# Brentford         3.933333   9.466667  0.033333  10.333333  3.866667
# Brighton          4.179245  10.952830  0.103774  10.386792  3.584906
# Burnley           3.953947  10.453947  0.059211   9.348684  3.315789
# Cardiff           4.184211   9.578947  0.052632   9.947368  2.894737
# Charlton          3.815789  11.578947  0.105263   7.631579  3.789474
# ...

# %%
import seaborn as sns

# %%
stat_correlations = df[stat_cols].corr()
sns.heatmap(stat_correlations, annot=True, annot_kws={'size': 7});

# %%
df_stats = df[stat_cols]

# %%
df_stats.head()
# Out:
#     AC    AF   AR    AS  AST   AY    HC    HF   HR    HS   HST   HY  margin
# 0  5.0  11.0  0.0  10.0  2.0  2.0   3.0  16.0  0.0  10.0   2.0  1.0    -2.0
# 1  4.0   9.0  0.0  11.0  4.0  0.0   4.0   7.0  0.0   9.0   3.0  2.0     0.0
# 2  5.0  16.0  0.0  15.0  2.0  3.0   5.0  18.0  0.0   7.0   3.0  3.0     2.0
# 3  4.0   9.0  0.0  15.0  6.0  0.0   6.0  13.0  0.0  12.0   4.0  2.0     1.0
# 4  1.0  14.0  0.0   5.0  0.0  3.0  11.0   9.0  0.0  23.0  10.0  0.0     2.0

# %%
df_stats['AC'].isna().value_counts()
# Out:
# False    6699
# True        1
# Name: AC, dtype: int64

# %%
df_stats['AF'].isna().value_counts()
# Out:
# False    6699
# True        1
# Name: AF, dtype: int64

# %%
df_stats['AR'].isna().value_counts()
# Out:
# False    6699
# True        1
# Name: AR, dtype: int64

# %%
for col in pearson_col:
    print(df_stats[col].isna().value_counts())
# Out:
# False    6699
# True        1
# Name: AC, dtype: int64
# False    6699
# True        1
# Name: AF, dtype: int64
# False    6699
# True        1
# Name: AR, dtype: int64
# False    6699
# True        1
# Name: AS, dtype: int64
# False    6699
# True        1
# Name: AST, dtype: int64
# False    6699
# True        1
# Name: AY, dtype: int64
# False    6699
# True        1
# Name: HC, dtype: int64
# False    6699
# True        1
# Name: HF, dtype: int64
# False    6699
# True        1
# Name: HR, dtype: int64
# False    6699
# True        1
# Name: HS, dtype: int64
# False    6699
# True        1
# Name: HST, dtype: int64
# False    6699
# True        1
# Name: HY, dtype: int64

# %%
df_stats = df_stats.dropna()
df_stats
# Out:
#       AC    AF   AR    AS  AST   AY    HC    HF   HR    HS   HST   HY  margin
# 0    5.0  11.0  0.0  10.0  2.0  2.0   3.0  16.0  0.0  10.0   2.0  1.0    -2.0
# 1    4.0   9.0  0.0  11.0  4.0  0.0   4.0   7.0  0.0   9.0   3.0  2.0     0.0
# 2    5.0  16.0  0.0  15.0  2.0  3.0   5.0  18.0  0.0   7.0   3.0  3.0     2.0
# 3    4.0   9.0  0.0  15.0  6.0  0.0   6.0  13.0  0.0  12.0   4.0  2.0     1.0
# 4    1.0  14.0  0.0   5.0  0.0  3.0  11.0   9.0  0.0  23.0  10.0  0.0     2.0
# ..   ...   ...  ...   ...  ...  ...   ...   ...  ...   ...   ...  ...     ...
# 375  4.0  12.0  0.0   6.0  3.0  1.0   8.0   8.0  0.0   8.0   3.0  0.0     1.0
# 376  2.0   6.0  0.0   8.0  3.0  0.0   8.0   9.0  0.0  20.0  11.0  1.0     4.0
# 377  7.0  14.0  0.0  10.0  5.0  2.0   3.0  17.0  1.0  16.0   8.0  4.0     1.0
# 378  6.0  11.0  0.0   8.0  4.0  0.0   5.0   5.0  0.0   6.0   4.0  1.0    -2.0
# 379  4.0   7.0  0.0  14.0  6.0  0.0  11.0  17.0  0.0  12.0   7.0  1.0     1.0
#
# [6699 rows x 13 columns]

# %%
df_stats['THC'] = df_stats['HY'] + df_stats['HR']
df_stats['TAC'] = df_stats['AY'] + df_stats['AR']
df_stats
# Out:
#       AC    AF   AR    AS  AST   AY    HC    HF   HR    HS   HST   HY  margin  \
# 0    5.0  11.0  0.0  10.0  2.0  2.0   3.0  16.0  0.0  10.0   2.0  1.0    -2.0
# 1    4.0   9.0  0.0  11.0  4.0  0.0   4.0   7.0  0.0   9.0   3.0  2.0     0.0
# 2    5.0  16.0  0.0  15.0  2.0  3.0   5.0  18.0  0.0   7.0   3.0  3.0     2.0
# 3    4.0   9.0  0.0  15.0  6.0  0.0   6.0  13.0  0.0  12.0   4.0  2.0     1.0
# 4    1.0  14.0  0.0   5.0  0.0  3.0  11.0   9.0  0.0  23.0  10.0  0.0     2.0
# ..   ...   ...  ...   ...  ...  ...   ...   ...  ...   ...   ...  ...     ...
# 375  4.0  12.0  0.0   6.0  3.0  1.0   8.0   8.0  0.0   8.0   3.0  0.0     1.0
# 376  2.0   6.0  0.0   8.0  3.0  0.0   8.0   9.0  0.0  20.0  11.0  1.0     4.0
# 377  7.0  14.0  0.0  10.0  5.0  2.0   3.0  17.0  1.0  16.0   8.0  4.0     1.0
# 378  6.0  11.0  0.0   8.0  4.0  0.0   5.0   5.0  0.0   6.0   4.0  1.0    -2.0
# 379  4.0   7.0  0.0  14.0  6.0  0.0  11.0  17.0  0.0  12.0   7.0  1.0     1.0
#
#      THC  TAC
# 0    1.0  2.0
# ...

# %%
from scipy import stats

# %%
stats.pearsonr(np.array(df_home['AC']), np.array(df_home['margin']))

# %%
pearson_col = ['AC', 'AF', 'AR', 'AS', 'AST', 'AY', 'HC', 'HF', 'HR', 'HS', 'HST', 'HY', 'THC', 'TAC']

# %%
for col in pearson_col:
    print(col, stats.pearsonr(np.array(df_home[col]), np.array(df_home['margin'])))
# Out:
# AC (-0.5501338116249612, 0.00016049805518829222)
# AF (0.031953213713796634, 0.8407906279591626)
# AR (0.01478894667514156, 0.9259385928831136)
# AS (-0.7573841952400341, 6.415177270523561e-09)
# AST (-0.6004818693753777, 2.6221563468967162e-05)
# AY (0.32200251400764673, 0.037563576183141406)
# HC (0.6249345212552029, 9.68966897102012e-06)
# HF (-0.23689892800462145, 0.13090500340508424)
# HR (-0.08942849185685013, 0.5732967100961138)
# HS (0.757743182413269, 6.250735992233225e-09)
# HST (0.5950232125042924, 3.238753351520744e-05)
# HY (-0.23914311753873785, 0.12718906105649413)

# %%
for col in pearson_col:
    print(col, stats.pearsonr(np.array(df_away[col]), np.array(df_away['margin'])))
# Out:
# AC (-0.7717948477854376, 2.1812394100595982e-09)
# AF (0.19467607965828496, 0.21666994736102801)
# AR (-0.3144798854581201, 0.042525441592073436)
# AS (-0.8123559648115078, 6.52879326668966e-11)
# AST (-0.7061835819113539, 1.743626556963043e-07)
# AY (-0.03606957277063409, 0.8205973274924375)
# HC (0.8036551704394411, 1.4827966069427814e-10)
# HF (-0.2918571889240425, 0.06073340942922481)
# HR (-0.4360113957387107, 0.003897066194050383)
# HS (0.7290584488954277, 4.3695849370611746e-08)
# HST (0.5268299343037448, 0.00033799504184084335)
# HY (-0.662761154528073, 1.737110194045811e-06)

# %%
for col in pearson_col:
    print(col, stats.pearsonr(np.array(df_stats[col]), np.array(df_stats['margin'])))
# Out:
# AC (-0.084155569986856, 5.241742563328664e-12)
# AF (-0.0017666733714742395, 0.8850497650620709)
# AR (0.10627730781041458, 2.742750839219571e-18)
# AS (-0.31723754998824627, 1.714425747920807e-156)
# AST (-0.3656346886817075, 5.330819210693126e-211)
# AY (0.011420961401020958, 0.34997785122590863)
# HC (0.08797948911201764, 5.451527155734497e-13)
# HF (-0.05497035901831823, 6.739742369734269e-06)
# HR (-0.13047270672122682, 7.962289603290464e-27)
# HS (0.29666913017711666, 3.45708551718046e-136)
# HST (0.39745473686175364, 2.2296649660544815e-252)
# HY (-0.15291551270867934, 2.473927430309455e-36)
# THC (-0.1742918885548804, 7.664916764235223e-47)
# TAC (0.03404171133100005, 0.005327834400483979)

# %%
def stats_features(df):
    stat_cols = ['AC', 'AF', 'AR', 'AS', 'AST', 'AY', 'HC', 'HF', 'HR', 'HS', 'HST', 'HY', 'margin']
    df['margin'] = df['FTHG'] - df['FTAG']
    df_stats = df[stat_cols]
    df_stats = df_stats.dropna()
    df_stats['THC'] = df_stats['HY'] + df_stats['HR']
    df_stats['TAC'] = df_stats['AY'] + df_stats['AR']
    final_cols = ['AST', 'HST', 'HC', 'AC', 'THC', 'TAC', 'margin']
    df_final = df_stats[final_cols]
    return df_final
